# %%
import xarray as xr
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ds = xr.open_dataset('ocean_flt.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (tracer: 2, boundary: 4, s_rho: 30, s_w: 31, Nuser: 25,
#                      ocean_time: 380, drifter: 10)
# Coordinates:
#   * s_rho           (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w             (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.06667 -0.03333 0.0
#   * ocean_time      (ocean_time) datetime64[ns] 2020-01-01T12:00:00 ... 2020-...
# Dimensions without coordinates: tracer, boundary, Nuser, drifter
# Data variables: (12/89)
#     ntimes          int32 ...
#     ndtfast         int32 ...
#     dt              float64 ...
#     dtfast          float64 ...
#     dstart          datetime64[ns] ...
#     nHIS            int32 ...
#     ...              ...
#     lon             (ocean_time, drifter) float32 ...
#     lat             (ocean_time, drifter) float32 ...
#     depth           (ocean_time, drifter) float32 ...
#     rho             (ocean_time, drifter) float32 ...
# ...

# %%
lat = ds['lat']
lon = ds['lon']
depth = ds['depth']

# %%
plt.plot(lon[:,0], lat[:,0])
plt.plot(lon[:,0], lat[:,0])

# %%
plt.plot(lon[:,1], lat[:,1])
plt.plot(lon[:,1], lat[:,1])
